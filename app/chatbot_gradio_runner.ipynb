# %% [markdown]
# # Generative AI for Audio Application

# %% [markdown]
# #### Restart Kernel (If needed)

# %%
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)

# %% [markdown]
# # Import Libraries
# Most of the complexity for the chatbot is in [customizable_chatbot.py](./customizable_chatbot.py) that uses [audio.py](./audio.py) internally for the audio capabilities.

# %%
import os
import gradio as gr
from genai_voice.bots.chatbot import ChatBot
from genai_voice.config.defaults import Config
from genai_voice.logger.log_utils import log, LogLevels
# Out:
# 11:52:30 HTTP Request: GET https://api.gradio.app/gradio-messaging/en "HTTP/1.1 200 OK"

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
log(f'Configuration: {Config()}', log_level=LogLevels.ON)
# Out:
# 11:52:38 Configuration:
#         Default(MODEL_GPT_TURBO_NAME='gpt-4-turbo',
#         OPENAI_API_KEY='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',
#         TEMPERATURE=0.0,
#         TOP_P=0.97,
#         TOP_K=40,
#         MAX_OUTPUT_TOKENS=2048,
#         WEB_SCRAP_OUTPUT_DIR=data/context.txt)

# %% [markdown]
# ## Set Current Working Directory
#
# We want to simulate running this notebook from the project root just as it would work when using `Poetry` scripts.

# %%
curr_wrk_dir = os.getcwd()
log(f'Before directory change: {curr_wrk_dir}')
if curr_wrk_dir.endswith('app'):
    log(f'Changing directory to root')
    os.chdir('..')
    curr_wrk_dir = os.getcwd()
log(f'Before directory change: {curr_wrk_dir}')
# Out:
# 11:52:40 Before directory change: /Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/app
# 11:52:40 Changing directory to root
# 11:52:40 Before directory change: /Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution

# %% [markdown]
# # Create Data for LLM Context
#
# `Poetry` scripts allow us to install our code as a package and run functions executables.
#
# We will use the `ExtractWebPagesAndSaveData` script, that is defined in `pyproject.toml` to scrape, extract and generate the file that the LLM will use as context data.
#
# `SAMPLE_URLS` have been defined under provided under `genai_voice.data_utils.urls.py`. Feel free to modify the links in that file to customize the source of data.
#
# > **DISCLAIMER:** Be responsible when scraping data that is not yours, complying with the EULA of the sites and conducting it in a legal fashion. Also remember that most sites will throttle scrapes, so do this with caution.
#
# > **NOTE:** This is an optional step. It just shows you have you can get custom data for your LLM context. We have provided the data for this project.

# %%
# !poetry run ExtractWebPagesAndSaveData

# %% [markdown]
# ## Gradio Interface
# This launches the UI, you will probably need to allow the browser to use the microphone to enable the audio functions.

# %%
"""Run Chatbot app"""
chatbot = ChatBot(enable_speakers=True, threaded=True)
history = []

def get_response(audio):
    """Get Audio Response From Chatbot"""
    if not audio:
        raise ValueError("No audio file provided.")
    prompt = chatbot.get_prompt_from_gradio_audio(audio)
    log(f"Transcribed prompt: {prompt}", log_level=LogLevels.ON)
    response = chatbot.respond(prompt, history)
    log(f"Chatbot response: {response}", log_level=LogLevels.ON)
    history.append([prompt, response])
    return response

demo = gr.Interface(
        get_response,
        gr.Audio(sources="microphone"),
        None,
        title="Wanderwise Travel Assistant"
)
demo.launch()
# Out:
# 11:52:45 Context file: travel_bot_context.txt
# 11:52:45 Creating the OpenAI Model Client.
# 11:52:45 Initialized OpenAI model: gpt-4-turbo
# 11:52:45 HTTP Request: GET http://127.0.0.1:7860/startup-events "HTTP/1.1 200 OK"
# 11:52:45 HTTP Request: HEAD http://127.0.0.1:7860/ "HTTP/1.1 200 OK"
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 11:52:45 HTTP Request: GET https://checkip.amazonaws.com/ "HTTP/1.1 200 "
# 11:52:45 HTTP Request: GET https://checkip.amazonaws.com/ "HTTP/1.1 200 "
# 11:52:46 HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# Traceback (most recent call last):
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1935, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1520, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2461, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 962, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/utils.py", line 826, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/var/folders/b8/syn10xln6jx1qcr4slbkhb100000gn/T/ipykernel_27018/968183284.py", line 8, in get_response
#     raise ValueError("No audio file provided.")
# ValueError: No audio file provided.
# Traceback (most recent call last):
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1935, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1520, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2461, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 962, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/utils.py", line 826, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/var/folders/b8/syn10xln6jx1qcr4slbkhb100000gn/T/ipykernel_27018/968183284.py", line 8, in get_response
#     raise ValueError("No audio file provided.")
# ValueError: No audio file provided.
# Traceback (most recent call last):
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1935, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1520, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2461, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 962, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/utils.py", line 826, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/var/folders/b8/syn10xln6jx1qcr4slbkhb100000gn/T/ipykernel_27018/968183284.py", line 8, in get_response
#     raise ValueError("No audio file provided.")
# ValueError: No audio file provided.
# 11:54:51 Getting prompt from audio device: (44100, array([  0,   0,   0, ..., -53, -52, -43], dtype=int16))
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/290M [00:00<?, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json: 0.00B [00:00, ?B/s]
# /Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# 11:56:09 Transcribed prompt:  I need some information regarding the traveling to the U.S.
# 11:56:09 Empty history. Creating a state list to track histories.
# 11:56:09 ModelGenerationConfig: temperature=0.0, top_p=0.97, top_k=40, max_output_tokens=2048, seed=0, response_format={'type': 'text'}
# 11:56:15 HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 11:56:15 Chatbot response: I'd be happy to help you with information about traveling to the U.S.! Could you please specify what kind of information you're looking for? For example, are you interested in visa requirements, popular destinations, travel restrictions, or something else? Additionally, could you let me know your country of origin, as this might affect visa and entry requirements?
# /Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pydub/utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# Error handling audio file: [Errno 2] No such file or directory: 'ffprobe'
# Traceback (most recent call last):
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1935, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1520, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2461, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 962, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/gradio/utils.py", line 826, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/var/folders/b8/syn10xln6jx1qcr4slbkhb100000gn/T/ipykernel_27018/968183284.py", line 8, in get_response
#     raise ValueError("No audio file provided.")
# ValueError: No audio file provided.
# 12:06:59 Getting prompt from audio device: (44100, array([   0,    0,    0, ..., -122, -120, -129], dtype=int16))
# /Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# 12:07:04 Transcribed prompt:  I need to travel from India to the US in the coming next six months. When can I plan my travel and how many maybe we plan for a month?
# 12:07:04 ModelGenerationConfig: temperature=0.0, top_p=0.97, top_k=40, max_output_tokens=2048, seed=0, response_format={'type': 'text'}
# 12:07:21 HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 12:07:21 Chatbot response: Traveling from India to the U.S. can be a fantastic experience! Here are a few key points to consider when planning your trip:
#
# 1. **Best Time to Travel**: The best time to visit the U.S. depends on where you plan to go. For instance, if you're visiting cities like New York or Washington D.C., spring (March to May) and fall (September to November) are ideal due to the mild weather. If you're planning to visit Florida or California, the weather is generally good year-round, but summers can be quite hot.
#
# 2. **Duration of Stay**: Planning for a month-long stay is great as it gives you ample time to explore multiple regions or cities. The U.S. is vast with diverse attractions ranging from natural wonders like the Grand Canyon to bustling cities like Los Angeles and cultural landmarks in New Orleans.
#
# 3. **Visa Requirements**: As an Indian citizen, you will need to apply for a tourist visa (B-2 visa) to visit the U.S. It's advisable to apply for a visa at least 3-4 months in advance of your travel date due to potential processing times and interview scheduling. You'll need to fill out the DS-160 form online and schedule an interview at the U.S. Embassy or Consulate in India.
#
# 4. **Travel and Health Insurance**: It's highly recommended to have travel and health insurance for your visit to the U.S., as healthcare can be very expensive.
#
# 5. **COVID-19 Guidelines**: Keep an eye on any travel advisories or COVID-19 guidelines that might affect your travel. Requirements can change based on the global health situation.
#
# 6. **Itinerary Planning**: Since you have a month, you could consider a multi-city tour. For example, you could start on the East Coast, visiting New York City, Washington D.C., and perhaps Florida, then fly to the West Coast to explore California (San Francisco, Los Angeles, and San Diego), and possibly include a visit to Las Vegas or national parks like Yosemite or the Grand Canyon.
#
# Would you like assistance with specific destinations, travel bookings, or more detailed planning for your trip?
# /Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pydub/utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# Exception in thread Thread-11 (communicate):
# Traceback (most recent call last):
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/genai_voice/processing/audio.py", line 53, in communicate
#     audio_file = AudioSegment.from_mp3(temp_file)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pydub/audio_segment.py", line 796, in from_mp3
#     return cls.from_file(file, 'mp3', parameters=parameters)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pydub/audio_segment.py", line 728, in from_file
#     info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pydub/utils.py", line 274, in mediainfo_json
#     res = Popen(command, stdin=stdin_parameter, stdout=PIPE, stderr=PIPE)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'ffprobe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/genai_voice/processing/audio.py", line 62, in communicate
#     engine.runAndWait()
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pyttsx3/engine.py", line 180, in runAndWait
#     raise RuntimeError('run loop already started')
# RuntimeError: run loop already started
# Error handling audio file: [Errno 2] No such file or directory: 'ffprobe'
# 12:08:29 Getting prompt from audio device: (44100, array([   0,    0,    0, ..., -122, -120, -129], dtype=int16))
# /Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# 12:08:33 Transcribed prompt:  I need to travel from India to the US in the coming next six months. When can I plan my travel and how many maybe we plan for a month?
# 12:08:33 ModelGenerationConfig: temperature=0.0, top_p=0.97, top_k=40, max_output_tokens=2048, seed=0, response_format={'type': 'text'}
# 12:08:56 HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 12:08:56 Chatbot response: Planning a month-long trip from India to the U.S. within the next six months is a great idea, and here are some steps and tips to help you organize your journey:
#
# ### 1. **Decide on Travel Dates**
# Given that you have a six-month window, consider the climate and events happening in the U.S. during this period. Spring (March to May) and fall (September to November) are generally pleasant times to visit most parts of the U.S. These seasons offer mild weather and are less crowded compared to summer.
#
# ### 2. **Visa Application**
# As an Indian citizen, you'll need a B-2 tourist visa to travel to the U.S. It's advisable to apply for your visa as soon as possible, as the process can take several weeks or even months. You'll need to fill out an online application form (DS-160), pay the visa fee, and schedule an interview at the U.S. Embassy or Consulate in India.
#
# ### 3. **Itinerary Planning**
# With a month at your disposal, you can explore multiple regions. Here’s a suggested breakdown:
#    - **Week 1:** East Coast (New York City, Washington D.C., Boston)
#    - **Week 2:** South (Orlando for theme parks, Miami, New Orleans)
#    - **Week 3:** West Coast (Los Angeles, San Francisco, San Diego)
#    - **Week 4:** National Parks and Las Vegas (Grand Canyon, Yosemite, Las Vegas)
#
# ### 4. **Booking Flights and Accommodations**
# - **Flights:** Look for round-trip flights from major Indian cities to major U.S. hubs. Booking in advance can help you get better rates.
# - **Accommodations:** Depending on your budget, you can choose from hotels, motels, Airbnb, or hostels. Booking accommodations well in advance is recommended, especially in tourist-heavy areas.
#
# ### 5. **Transportation Within the U.S.**
# - **Domestic Flights:** For longer distances, consider domestic flights as the U.S. is quite large.
# - **Car Rental:** Renting a car is a good option if you're comfortable driving long distances. It offers flexibility, especially for exploring national parks and rural areas.
# - **Public Transportation:** Cities like New York, San Francisco, and Washington D.C. have good public transport systems.
#
# ### 6. **Travel Insurance**
# It’s crucial to have travel and health insurance that covers the duration of your stay in the U.S., considering the high cost of healthcare.
#
# ### 7. **Packing and Preparation**
# Pack according to the season and regions you are visiting. Always include travel adapters, essential medications, and copies of important documents.
#
# ### 8. **Stay Updated on Travel Guidelines**
# Keep an eye on any travel advisories, including COVID-19 regulations or any changes in visa policies.
#
# Would you like more detailed information on any specific destinations, tips on attractions, or help with booking arrangements?
# /Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pydub/utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# Exception in thread Thread-12 (communicate):
# Traceback (most recent call last):
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/genai_voice/processing/audio.py", line 53, in communicate
#     audio_file = AudioSegment.from_mp3(temp_file)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pydub/audio_segment.py", line 796, in from_mp3
#     return cls.from_file(file, 'mp3', parameters=parameters)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pydub/audio_segment.py", line 728, in from_file
#     info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pydub/utils.py", line 274, in mediainfo_json
#     res = Popen(command, stdin=stdin_parameter, stdout=PIPE, stderr=PIPE)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'ffprobe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/genai_voice/processing/audio.py", line 62, in communicate
#     engine.runAndWait()
#   File "/Users/bharathmanda/Downloads/8. Conversational Audio Bot Project/Solution/.venv/lib/python3.12/site-packages/pyttsx3/engine.py", line 180, in runAndWait
#     raise RuntimeError('run loop already started')
# RuntimeError: run loop already started
# Error handling audio file: [Errno 2] No such file or directory: 'ffprobe'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
